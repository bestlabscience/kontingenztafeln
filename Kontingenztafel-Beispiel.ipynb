# %% [markdown]
# # Beispiel zu Pflanzen

# %%
tafel <- as.table(matrix(c(65, 313,21, 281),2))

# %%
dimnames(tafel)[[1]] <- c("R", "NR")
dimnames(tafel)[[2]] <- c("kurz", "lang")

# %% [markdown]
# ### $\chi^2$-Test

# %%
chisq.test(tafel, correct=FALSE)
